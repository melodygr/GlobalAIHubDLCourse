# %% [markdown]
# ### Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.datasets import mnist
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from keras.optimizers import RMSprop
import pylab as plt

# %% [markdown]
# #### Keras is the deep learning library that helps you to code Deep Neural Networks with fewer lines of code

# %% [markdown]
# ### Import data

# %%
batch_size = 128
num_classes = 10
epochs = 2

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize to 0 to 1 range
x_train /= 255
x_test /= 255

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # Part 1: Analysis of Activation Functions

# %% [markdown]
# ### Try other Activation Functions
# Analyze the accuracy and training time
# #### Example Syntax
# * model.add(Dense(8, activation='tanh'))
# * model.add(Dense(8, activation='linear'))
# * model.add(Dense(8, activation='relu'))
# * model.add(Dense(8, activation='hard_sigmoid'))

# %% [markdown]
# ### Sigmoid Activation Function

# %%
model = Sequential()
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 4s 4ms/step - loss: 1.3583 - accuracy: 0.7003 - val_loss: 0.3443 - val_accuracy: 0.9065
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3092 - accuracy: 0.9146 - val_loss: 0.2397 - val_accuracy: 0.9284
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2296 - accuracy: 0.9329 - val_loss: 0.1965 - val_accuracy: 0.9408
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1902 - accuracy: 0.9447 - val_loss: 0.1690 - val_accuracy: 0.9494
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1597 - accuracy: 0.9542 - val_loss: 0.1483 - val_accuracy: 0.9548
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1407 - accuracy: 0.9589 - val_loss: 0.1354 - val_accuracy: 0.9594
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1231 - accuracy: 0.9633 - val_loss: 0.1244 - val_accuracy: 0.9621
# Epoch 8/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9677 - val_loss: 0.1166 - val_accuracy: 0.9644
# Epoch 9/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0950 - accuracy: 0.9725 - val_loss: 0.1130 - val_accuracy: 0.9662
# Epoch 10/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0886 - accuracy: 0.9744 - val_loss: 0.1042 - val_accuracy: 0.9681
# Test loss: 0.1041656881570816
# Test accuracy: 0.9681000113487244

# %% [markdown]
# ### Relu Activation Function

# %%
# Write your code here. Use the same architecture as above.

# %% [markdown]
# ### Write your findings about activations here?
#
# 1.   Finding 1
# 2.   Finding 2

# %% [markdown]
# # Part 2: Design Choices: Nodes
# #### Analyze the parameter size, accuracy and training time

# %% [markdown]
# ### Design a model with small Number of Nodes. For Example 8

# %%
first_layer_size = 8

model = Sequential()
model.add(Dense(first_layer_size, activation='sigmoid', input_shape=(784,)))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

w = []
for layer in model.layers:
    weights = layer.get_weights()
    w.append(weights)

layer1 = np.array(w[0][0])
print("Shape of First Layer",layer1.shape)
print("Visualization of First Layer")

import matplotlib.pyplot as plt
fig=plt.figure(figsize=(16, 16))
columns = 8
rows = int(first_layer_size/8)
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(layer1[:,i-1].reshape(28,28),cmap='gray')
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 8)                 6280
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                288
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                330
# =================================================================
# Total params: 6,898
# Trainable params: 6,898
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/2
# 60000/60000 [==============================] - 15s - loss: 1.8398 - acc: 0.5610 - val_loss: 1.3080 - val_acc: 0.7207
# Epoch 2/2
# 60000/60000 [==============================] - 11s - loss: 0.9784 - acc: 0.7753 - val_loss: 0.7332 - val_acc: 0.8147
# Test loss: 0.7331901484489441
# Test accuracy: 0.8147
# Shape of First Layer (784, 8)
# Visualization of First Layer

# %% [markdown]
# ### Design a model with large Number of Nodes. For example 128

# %%
# Write your code here 

# Use the same layer design from the above cell. Play with the parameter "first_layer_size" above. 
# It is preferred to have first_layer_size as multiplication of 8 (for visualizing the weights properly)

# %% [markdown]
# ### Write your findings about influence of nodes here?
#
# 1.   Finding 1
# 2.   Finding 2

# %% [markdown]
# # Part 3: Design Choices: Layers
# #### Analyze the parameter size, accuracy and training time

# %% [markdown]
# ### Design a model with small number of layers. For example 1 hidden layer

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(784,)))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.7565 - accuracy: 0.7996 - val_loss: 0.2641 - val_accuracy: 0.9260
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2532 - accuracy: 0.9283 - val_loss: 0.2173 - val_accuracy: 0.9372
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2057 - accuracy: 0.9418 - val_loss: 0.1896 - val_accuracy: 0.9446
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1735 - accuracy: 0.9494 - val_loss: 0.1643 - val_accuracy: 0.9524
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1543 - accuracy: 0.9554 - val_loss: 0.1542 - val_accuracy: 0.9563
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1372 - accuracy: 0.9598 - val_loss: 0.1514 - val_accuracy: 0.9556
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1272 - accuracy: 0.9641 - val_loss: 0.1414 - val_accuracy: 0.9573
# Epoch 8/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1202 - accuracy: 0.9652 - val_loss: 0.1388 - val_accuracy: 0.9597
# Epoch 9/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1102 - accuracy: 0.9680 - val_loss: 0.1311 - val_accuracy: 0.9612
# Epoch 10/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1027 - accuracy: 0.9697 - val_loss: 0.1294 - val_accuracy: 0.9632
# Test loss: 0.12942270934581757
# Test accuracy: 0.9631999731063843

# %% [markdown]
# ### Lower number of Layers. For example 4 hidden layers

# %%
# Write your code here 

# Use the same number of units from the above cell

# %% [markdown]
# ### Write your findings about influence of layers here?
#
# 1.   Finding 1
# 2.   Finding 2
